# %% [markdown]
# ## Algo Trading

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\saharsh\anaconda3\lib\site-packages (0.2.12)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\saharsh\anaconda3\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: requests>=2.26 in c:\users\saharsh\anaconda3\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\saharsh\anaconda3\lib\site-packages (from yfinance) (1.24.4)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\saharsh\anaconda3\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: html5lib>=1.1 in c:\users\saharsh\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\saharsh\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\saharsh\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\saharsh\anaconda3\lib\site-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\saharsh\anaconda3\lib\site-packages (from yfinance) (2.3.5)
# Requirement already satisfied: cryptography>=3.3.2 in c:\users\saharsh\anaconda3\lib\site-packages (from yfinance) (37.0.1)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\saharsh\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: soupsieve>1.2 in c:\users\saharsh\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\saharsh\anaconda3\lib\site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: webencodings in c:\users\saharsh\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\saharsh\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\saharsh\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\saharsh\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saharsh\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\saharsh\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\saharsh\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.26.11)
# Requirement already satisfied: pycparser in c:\users\saharsh\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\saharsh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\saharsh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\saharsh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\saharsh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\saharsh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\saharsh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\saharsh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\saharsh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\saharsh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\saharsh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\saharsh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\saharsh\anaconda3\lib\site-packages)

# %%
import yfinance as yf 
import pandas as pd

# %%
df = yf.download('WIPRO.NS')
df1 = yf.download('RVNL.NS')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
#                Open     High      Low    Close  Adj Close  Volume
# Date
# 1996-01-01  0.56250  0.56250  0.56250  0.56250   0.391560   39999
# 1996-01-02  0.51875  0.51875  0.51875  0.51875   0.361106   79999
# 1996-01-03  0.53750  0.53750  0.53750  0.53750   0.374157   39999
# 1996-01-04  0.53750  0.53750  0.53750  0.53750   0.374157  239999
# 1996-01-05  0.53750  0.53750  0.53750  0.53750   0.374157       0

# %%
df1.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2019-04-11  19.000000  19.799999  18.650000  19.049999  15.840137  89144982
# 2019-04-12  19.299999  19.900000  19.200001  19.750000  16.422190  29799546
# 2019-04-15  20.000000  23.700001  19.900000  23.650000  19.665052  80684771
# 2019-04-16  24.500000  26.950001  24.200001  25.600000  21.286482  98193853
# 2019-04-18  26.350000  26.850000  25.150000  26.150000  21.743811  49134384

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2025-02-03  303.000000  314.000000  300.299988  313.600006  313.600006
# 2025-02-04  318.000000  318.850006  313.350006  316.250000  316.250000
# 2025-02-05  317.799988  321.450012  314.899994  317.100006  317.100006
# 2025-02-06  320.000000  323.600006  314.549988  317.950012  317.950012
# 2025-02-07  319.000000  319.000000  314.000000  318.000000  318.000000
#
#               Volume
# Date
# 2025-02-03  14877076
# 2025-02-04  15366864
# 2025-02-05   9628027
# 2025-02-06  15062390
# 2025-02-07   8585646

# %%
df1.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2025-02-03  415.149994  419.899994  398.000000  407.149994  407.149994
# 2025-02-04  416.000000  421.299988  394.700012  400.100006  400.100006
# 2025-02-05  411.600006  416.299988  404.000000  406.299988  406.299988
# 2025-02-06  406.399994  411.700012  401.700012  403.049988  403.049988
# 2025-02-07  401.000000  403.000000  393.750000  395.049988  395.049988
#
#               Volume
# Date
# 2025-02-03  22386317
# 2025-02-04  15907300
# 2025-02-05  10360639
# 2025-02-06   4336358
# 2025-02-07   4891361

# %%
import numpy as np
import math
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense 
from tensorflow.keras.layers import LSTM

# %%
## Historical Data Visualization

# %%
plt.figure(figsize=(16,8))
plt.title('historical price of WIPRO')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close_Price', fontsize=18)
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.title('historical price of RVNL')
plt.plot(df1['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close_Price', fontsize=18)
plt.show()

# %%
data = df.filter(['Close'])
df = np.array(data).reshape(-1,1)
df
# Out:
# array([[  0.5625    ],
#        [  0.51875001],
#        [  0.53750002],
#        ...,
#        [317.1000061 ],
#        [317.95001221],
#        [318.        ]])

# %%
data = df1.filter(['Close'])
df1 = np.array(data).reshape(-1,1)
df1
# Out:
# array([[ 19.04999924],
#        [ 19.75      ],
#        [ 23.64999962],
#        ...,
#        [406.29998779],
#        [403.04998779],
#        [395.04998779]])

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_df = scaler.fit_transform(np.array(df).reshape(-1,1))
scaled_df
# Out:
# array([[4.96023166e-04],
#        [3.74618934e-04],
#        [4.26649366e-04],
#        ...,
#        [8.78873247e-01],
#        [8.81231975e-01],
#        [8.81370689e-01]])

# %%
scaled_df 
training_data_len = math.ceil(len(scaled_df)*0.8)
training_data_len
# Out:
# 5850

# %%
train_data = scaled_df[0:training_data_len , :]
x_train = []
y_train = []
for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
    if i<= 60:
        print(x_train)
        print(y_train)
        print()
# Out:
# [array([0.00049602, 0.00037462, 0.00042665, 0.00042665, 0.00042665,
#        0.00042665, 0.00042665, 0.00042873, 0.00042665, 0.00042665,
#        0.00042665, 0.00039196, 0.00039196, 0.00041971, 0.00039196,
#        0.00041971, 0.00039196, 0.00039196, 0.00039196, 0.00039196,
#        0.00039196, 0.00037999, 0.00037999, 0.00037999, 0.00042665,
#        0.00042665, 0.00039196, 0.00039196, 0.00039196, 0.00039196,
#        0.0004263 , 0.0004263 , 0.0004263 , 0.0004263 , 0.00049602,
#        0.00049602, 0.00049602, 0.00049602, 0.00049602, 0.00049602,
#        0.00049602, 0.00044399, 0.00049602, 0.00049602, 0.00049602,
#        0.00049602, 0.00049602, 0.00049602, 0.00049602, 0.00048735,
#        0.00048735, 0.00049602, 0.00039213, 0.00039213, 0.00041277,
#        0.00046134, 0.00046151, 0.00046151, 0.00046151, 0.00046151])]
# [0.0004615082824551259]

# %%
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_train.shape
# Out:
# (5790, 60, 1)

# %%
model = Sequential()
model.add(LSTM(50,return_sequences = True, input_shape = (x_train.shape[1],1)))
model.add(Dense(25))
model.add(Dense(1))

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.fit(x_train, y_train, batch_size=40, epochs=20)
# Out:
# Epoch 1/20
# 145/145 [==============================] - 4s 14ms/step - loss: 0.0108
# Epoch 2/20
# 145/145 [==============================] - 2s 13ms/step - loss: 0.0101
# Epoch 3/20
# 145/145 [==============================] - 2s 14ms/step - loss: 0.0101
# Epoch 4/20
# 145/145 [==============================] - 2s 15ms/step - loss: 0.0101
# Epoch 5/20
# 145/145 [==============================] - 2s 14ms/step - loss: 0.0101
# Epoch 6/20
# 145/145 [==============================] - 2s 14ms/step - loss: 0.0101
# Epoch 7/20
# 145/145 [==============================] - 2s 14ms/step - loss: 0.0102
# Epoch 8/20
# 145/145 [==============================] - 2s 14ms/step - loss: 0.0101
# Epoch 9/20
# 145/145 [==============================] - 2s 15ms/step - loss: 0.0101
# Epoch 10/20
# 145/145 [==============================] - 2s 14ms/step - loss: 0.0101
# Epoch 11/20
# 145/145 [==============================] - 2s 14ms/step - loss: 0.0101
# Epoch 12/20
# 145/145 [==============================] - 2s 14ms/step - loss: 0.0101
# Epoch 13/20
# 145/145 [==============================] - 2s 14ms/step - loss: 0.0101
# Epoch 14/20
# 145/145 [==============================] - 2s 14ms/step - loss: 0.0102
# Epoch 15/20
# 145/145 [==============================] - 2s 14ms/step - loss: 0.0101
# Epoch 16/20
# 145/145 [==============================] - 2s 13ms/step - loss: 0.0101
# Epoch 17/20
# 145/145 [==============================] - 2s 14ms/step - loss: 0.0101
# Epoch 18/20
# 145/145 [==============================] - 2s 13ms/step - loss: 0.0101
# Epoch 19/20
# 145/145 [==============================] - 2s 14ms/step - loss: 0.0101
# Epoch 20/20
# 145/145 [==============================] - 2s 14ms/step - loss: 0.0101

# %%
test_data = scaled_df[training_data_len - 60: , :]
x_test = []
y_test = df[training_data_len: , :]
for i in range(60,len(test_data)):
    x_test.append(test_data[i-60:i, 0])

# %%
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)
rmse = np.sqrt(np.mean(predictions-y_test)**2)
rmse
# Out:
# 46/46 [==============================] - 1s 6ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_40288\155669296.py in <module>
#       1 predictions = model.predict(x_test)
# ----> 2 predictions = scaler.inverse_transform(predictions)
#       3 rmse = np.sqrt(np.mean(predictions-y_test)**2)
#       4 rmse
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in inverse_transform(self, X)
#     542         check_is_fitted(self)
#     543
# --> 544         X = check_array(
#     545             X, copy=self.copy, dtype=FLOAT_DTYPES, force_all_finite="allow-nan"
#     546         )
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     949             )
#     950         if not allow_nd and array.ndim >= 3:
# --> 951             raise ValueError(
#     952                 "Found array with dim %d. %s expected <= 2."
#     953                 % (array.ndim, estimator_name)
#
# ValueError: Found array with dim 3. None expected <= 2.

# %%
## Visualization of Test Data VS Predcited Data

# %%
train = data[:training_data_len]
val = data[training_data_len:]
val['predictions'] = predictions
plt.figure(figsize=(16, 8))
plt.title('model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close_Price', fontsize=18)
plt.plot(train['Close'])
plt.plot(val[['Close','predictions']],)
plt.legend(['train', 'val', 'predictions'], loc = 'lower right')
plt.show()
# Out:
# C:\Users\saharsh\AppData\Local\Temp\ipykernel_40288\3699947006.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val['predictions'] = predictions
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_40288\3699947006.py in <module>
#       7 plt.ylabel('Close_Price', fontsize=18)
#       8 plt.plot(train['Close'])
# ----> 9 plt.plot(val[['Close','predictions']],)
#      10 plt.legend(['train', 'val', 'predictions'], loc = 'lower right')
#      11 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     488             y = _check_1d(xy[1])
#     489         else:
# --> 490             x, y = index_of(xy[-1])
#     491
#     492         if self.axes.xaxis is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in index_of(y)
#    1608     """
#    1609     try:
# -> 1610         return y.index.to_numpy(), y.to_numpy()
#    1611     except AttributeError:
#    1612         pass
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in to_numpy(self, dtype, copy, na_value)
#    1754         if dtype is not None:
#    1755             dtype = np.dtype(dtype)
# -> 1756         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1757         if result.dtype is not dtype:
#    1758             result = np.array(result, dtype=dtype, copy=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in as_array(self, dtype, copy, na_value)
#    1597                     arr = arr.astype(dtype, copy=False)
#    1598         else:
# -> 1599             arr = self._interleave(dtype=dtype, na_value=na_value)
#    1600             # The underlying data was copied within _interleave
#    1601             copy = False
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _interleave(self, dtype, na_value)
#    1662             else:
#    1663                 arr = blk.get_values(dtype)
# -> 1664             result[rl.indexer] = arr
#    1665             itemmask[rl.indexer] = 1
#    1666
#
# ValueError: could not broadcast input array from shape (60,1) into shape (1,1462)

# %%
test = df[training_data_len:]
plt.figure(figsize=(16,8))
plt.title('historical price')
plt.plot(test)
plt.plot(predictions)
plt.xlabel('Days', fontsize=18)
plt.ylabel('Close_Price', fontsize=18)
plt.legend(['test', 'predictions'], loc = 'lower right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_40288\3049783373.py in <module>
#       3 plt.title('historical price')
#       4 plt.plot(test)
# ----> 5 plt.plot(predictions)
#       6 plt.xlabel('Days', fontsize=18)
#       7 plt.ylabel('Close_Price', fontsize=18)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     499                              f"have shapes {x.shape} and {y.shape}")
#     500         if x.ndim > 2 or y.ndim > 2:
# --> 501             raise ValueError(f"x and y can be no greater than 2D, but have "
#     502                              f"shapes {x.shape} and {y.shape}")
#     503         if x.ndim == 1:
#
# ValueError: x and y can be no greater than 2D, but have shapes (1462,) and (1462, 60, 1)

# %% [markdown]
# ## Practiced by K.Saharsh
